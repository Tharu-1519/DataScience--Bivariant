# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio
pio.renderers.default="svg"

# %%
##pip install plotly

# %%
dataset=pd.read_csv("Zomato_Mumbai_Dataset.csv",delimiter='|')
dataset
# Out:
#                     NAME PRICE  \
# 0                Hitchki  1200
# 1           Baba Falooda   400
# 2          Chin Chin Chu  1800
# 3         Butterfly High  1000
# 4              BKC  DIVE  1200
# ...                  ...   ...
# 15076  Hari Om Snack Bar   350
# 15077           PitaBurg   400
# 15078     Uncha Otlawala   300
# 15079     Mandarin Panda   400
# 15080                     NaN
#
#                                          CUSINE_CATEGORY    CITY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...  Mumbai
# 1                           Desserts,Ice Cream,Beverages  Mumbai
# 2                                          Asian,Chinese  Mumbai
# 3                                          Modern Indian  Mumbai
# 4                       North Indian,Chinese,Continental  Mumbai
# ...                                                  ...     ...
# 15076                     Fast Food,South Indian,Chinese  Mumbai
# ...

# %%
#number of first 10 rows display from dataset
dataset.head(20)
# Out:
#                     NAME  PRICE  \
# 0                Hitchki   1200
# 1           Baba Falooda    400
# 2          Chin Chin Chu   1800
# 3         Butterfly High   1000
# 4              BKC  DIVE   1200
# 5       Flea Bazaar Café    800
# 6         Persian Darbar   1300
# 7                Tanatan   1500
# 8             Cafe Safar    600
# 9     Plum by Bent Chair   1800
# 10         Angrezi Dhaba   1500
# 11                Raasta   1200
# 12      Todi Mill Social   1400
# 13  Burn - Bar & Kitchen   1100
# 14            145 Bandra   1300
# 15                  NAME  PRICE
# 16              Cafe Zoe   2000
# 17               Ustaadi   1200
# 18             Cafe Maaz    350
# 19         Carter's Blue    900
#
#                                       CUSINE_CATEGORY    CITY  \
# 0   Modern Indian,North Indian,Chinese,Momos,Birya...  Mumbai
# 1                        Desserts,Ice Cream,Beverages  Mumbai
# 2                                       Asian,Chinese  Mumbai
# ...

# %%
#number of last 10 rows display from dataset
dataset.tail(10)
# Out:
#                      NAME PRICE                 CUSINE_CATEGORY    CITY  \
# 15071       Lucknow Zaika   500            North Indian,Chinese  Mumbai
# 15072      Zuha's Kitchen   400    Chinese,North Indian,Mughlai  Mumbai
# 15073    Tapri - The Cafe   300             Fast Food,Beverages  Mumbai
# 15074  Suleman Mithaiwala   300                          Mithai  Mumbai
# 15075     Tirupati Balaji   500  Chinese,Fast Food,North Indian  Mumbai
# 15076   Hari Om Snack Bar   350  Fast Food,South Indian,Chinese  Mumbai
# 15077            PitaBurg   400              Fast Food,Lebanese  Mumbai
# 15078      Uncha Otlawala   300              Desserts,Ice Cream  Mumbai
# 15079      Mandarin Panda   400           Desserts,Chinese,Thai  Mumbai
# 15080                      NaN                             NaN     NaN
#
#                         REGION  \
# 15071                    Kurla
# 15072           Mumbai Central
# 15073              Mulund West
# 15074           Mumbai Central
# ...

# %%
dataset.shape
# Out:
# (15081, 12)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15081 entries, 0 to 15080
# Data columns (total 12 columns):
# NAME               15081 non-null object
# PRICE              15080 non-null object
# CUSINE_CATEGORY    15079 non-null object
# CITY               15080 non-null object
# REGION             15080 non-null object
# URL                15080 non-null object
# PAGE NO            15080 non-null object
# CUSINE TYPE        15080 non-null object
# TIMING             15015 non-null object
# RATING_TYPE        15080 non-null object
# RATING             15080 non-null object
# VOTES              15080 non-null object
# dtypes: object(12)
# memory usage: 1.4+ MB

# %%
dataset.isna().sum()
# Out:
# NAME                0
# PRICE               1
# CUSINE_CATEGORY     2
# CITY                1
# REGION              1
# URL                 1
# PAGE NO             1
# CUSINE TYPE         1
# TIMING             66
# RATING_TYPE         1
# RATING              1
# VOTES               1
# dtype: int64

# %%
dataset.describe()
# Out:
#          NAME  PRICE  CUSINE_CATEGORY    CITY  REGION    URL  PAGE NO  \
# count   15081  15080            15079   15080   15080  15080    15080
# unique  12720     67             3183       2     241  13823      944
# top      NAME    400  CUSINE_CATEGORY  Mumbai  REGION    URL  PAGE NO
# freq      942   2042              942   14138     942    942      942
#
#         CUSINE TYPE                 TIMING RATING_TYPE RATING  VOTES
# count         15080                  15015       15080  15080  15080
# unique           23                   2551          32     35   1124
# top     Quick Bites  11am to 11pm(Mon-Sun)     Average      -      -
# freq           5262                   1192        5112   2360   2360

# %%
wrong_PageNo = dataset['PAGE NO']=='PAGE NO'
dataset[wrong_PageNo]
# Out:
#        NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE  \
# 15     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 31     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 47     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 63     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 79     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# ...     ...    ...              ...   ...     ...  ...      ...          ...
# 15000  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15016  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15032  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15048  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15064  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
#
#        TIMING  RATING_TYPE  RATING  VOTES
# ...

# %%
dataset=dataset[~wrong_PageNo]
dataset
# Out:
#                     NAME PRICE  \
# 0                Hitchki  1200
# 1           Baba Falooda   400
# 2          Chin Chin Chu  1800
# 3         Butterfly High  1000
# 4              BKC  DIVE  1200
# ...                  ...   ...
# 15076  Hari Om Snack Bar   350
# 15077           PitaBurg   400
# 15078     Uncha Otlawala   300
# 15079     Mandarin Panda   400
# 15080                     NaN
#
#                                          CUSINE_CATEGORY    CITY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...  Mumbai
# 1                           Desserts,Ice Cream,Beverages  Mumbai
# 2                                          Asian,Chinese  Mumbai
# 3                                          Modern Indian  Mumbai
# 4                       North Indian,Chinese,Continental  Mumbai
# ...                                                  ...     ...
# 15076                     Fast Food,South Indian,Chinese  Mumbai
# ...

# %%
dataset.drop(['URL','PAGE NO','CITY'],axis=1,inplace=True)
# Out:
# C:\Anaconda3\envs\test\lib\site-packages\pandas\core\frame.py:4117: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dataset
# Out:
#                     NAME PRICE  \
# 0                Hitchki  1200
# 1           Baba Falooda   400
# 2          Chin Chin Chu  1800
# 3         Butterfly High  1000
# 4              BKC  DIVE  1200
# ...                  ...   ...
# 15076  Hari Om Snack Bar   350
# 15077           PitaBurg   400
# 15078     Uncha Otlawala   300
# 15079     Mandarin Panda   400
# 15080                     NaN
#
#                                          CUSINE_CATEGORY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...
# 1                           Desserts,Ice Cream,Beverages
# 2                                          Asian,Chinese
# 3                                          Modern Indian
# 4                       North Indian,Chinese,Continental
# ...                                                  ...
# 15076                     Fast Food,South Indian,Chinese
# 15077                                 Fast Food,Lebanese
# 15078                                 Desserts,Ice Cream
# ...

# %%
dataset.isna().sum()
# Out:
# NAME                0
# PRICE               1
# CUSINE_CATEGORY     2
# REGION              1
# CUSINE TYPE         1
# TIMING             66
# RATING_TYPE         1
# RATING              1
# VOTES               1
# dtype: int64

# %%
dataset[dataset['PRICE'].isna()]
# Out:
#       NAME PRICE CUSINE_CATEGORY REGION CUSINE TYPE TIMING RATING_TYPE RATING  \
# 15080       NaN             NaN    NaN         NaN    NaN         NaN    NaN
#
#       VOTES
# 15080   NaN

# %%
dataset=dataset.drop(labels=15080,axis=0)

# %%
dataset[dataset['PRICE'].isna()]
# Out:
# Empty DataFrame
# Columns: [NAME, PRICE, CUSINE_CATEGORY, REGION, CUSINE TYPE, TIMING, RATING_TYPE, RATING, VOTES]
# Index: []

# %%
dataset.isna().sum()
# Out:
# NAME                0
# PRICE               0
# CUSINE_CATEGORY     1
# REGION              0
# CUSINE TYPE         0
# TIMING             65
# RATING_TYPE         0
# RATING              0
# VOTES               0
# dtype: int64

# %%
dataset[dataset['CUSINE_CATEGORY'].isna()]
# Out:
#                 NAME PRICE CUSINE_CATEGORY   REGION CUSINE TYPE  \
# 7338  Mother's Taste   400             NaN  Bhandup        none
#
#                      TIMING RATING_TYPE RATING VOTES
# 7338  11am to 11pm(Mon-Sun)        Good    3.5    57

# %%
dataset.fillna('NA',inplace=True)

# %%
dataset.isna().sum()
# Out:
# NAME               0
# PRICE              0
# CUSINE_CATEGORY    0
# REGION             0
# CUSINE TYPE        0
# TIMING             0
# RATING_TYPE        0
# RATING             0
# VOTES              0
# dtype: int64

# %%
dataset['RATING'].value_counts()
# Out:
# -          2360
# 3.5        1094
# 3.4        1036
# 3.6         960
# NEW         953
# 3.3         926
# 3.7         917
# 3.2         801
# 3.8         782
# 3.1         734
# 3.0         622
# 3.9         596
# 2.9         409
# 4.0         408
# 2.8         309
# 4.1         298
# 4.2         199
# 2.7         170
# 4.3         148
# 4.4          99
# 2.6          77
# Opening      57
# 4.5          46
# 2.5          39
# 4.6          32
# 2.4          26
# 4.7          13
# 2.3          10
# 2.1           5
# 2.2           4
# 4.8           4
# 4.9           2
# 1.8           1
# 2.0           1
# Name: RATING, dtype: int64

# %%
dataset['RATING'].replace(to_replace=['-','NEW','Opening'],value=0,inplace=True)

# %%
dataset['RATING'].value_counts()
# Out:
# 0      3370
# 3.5    1094
# 3.4    1036
# 3.6     960
# 3.3     926
# 3.7     917
# 3.2     801
# 3.8     782
# 3.1     734
# 3.0     622
# 3.9     596
# 2.9     409
# 4.0     408
# 2.8     309
# 4.1     298
# 4.2     199
# 2.7     170
# 4.3     148
# 4.4      99
# 2.6      77
# 4.5      46
# 2.5      39
# 4.6      32
# 2.4      26
# 4.7      13
# 2.3      10
# 2.1       5
# 2.2       4
# 4.8       4
# 4.9       2
# 1.8       1
# 2.0       1
# Name: RATING, dtype: int64

# %%
dataset['VOTES'].value_counts()
# Out:
# -       2360
# NEW      953
# 4        364
# 5        320
# 6        288
#         ...
# 847        1
# 1255       1
# 1335       1
# 268        1
# 2998       1
# Name: VOTES, Length: 1123, dtype: int64

# %%
dataset['VOTES'].replace(to_replace=['-','NEW','Opening'],value=0,inplace=True)

# %%
dataset['VOTES'].value_counts()
# Out:
# 0       3370
# 4        364
# 5        320
# 6        288
# 7        277
#         ...
# 1457       1
# 3252       1
# 1495       1
# 2411       1
# 1515       1
# Name: VOTES, Length: 1121, dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14138 entries, 0 to 15079
# Data columns (total 9 columns):
# NAME               14138 non-null object
# PRICE              14138 non-null object
# CUSINE_CATEGORY    14138 non-null object
# REGION             14138 non-null object
# CUSINE TYPE        14138 non-null object
# TIMING             14138 non-null object
# RATING_TYPE        14138 non-null object
# RATING             14138 non-null object
# VOTES              14138 non-null object
# dtypes: object(9)
# memory usage: 1.1+ MB

# %%
dataset['PRICE']=dataset['PRICE'].astype('int64')
dataset['RATING']=dataset['RATING'].astype('float64')
dataset['VOTES']=dataset['VOTES'].astype('int64')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14138 entries, 0 to 15079
# Data columns (total 9 columns):
# NAME               14138 non-null object
# PRICE              14138 non-null int64
# CUSINE_CATEGORY    14138 non-null object
# REGION             14138 non-null object
# CUSINE TYPE        14138 non-null object
# TIMING             14138 non-null object
# RATING_TYPE        14138 non-null object
# RATING             14138 non-null float64
# VOTES              14138 non-null int64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 1.1+ MB

# %%
dataset['TIMING'].value_counts()
# Out:
# 11am to 11pm(Mon-Sun)                               1192
# 11am to 12midnight(Mon-Sun)                          632
# 12noon to 12midnight(Mon-Sun)                        467
# 11am to 1130pm(Mon-Sun)                              309
# 10am to 10pm(Mon-Sun)                                267
#                                                     ...
# Closed(Mon),1145am to 315pm,7pm to 1130pm...           1
# 11am to 230pm,6pm to 1130pm(Mon-Sun)                   1
# 12noon to 4pm,7pm to 11pm(Mon-Thu),12noon to ...       1
# 12noon to 5pm,630pm to 2am(Mon-Sun)                    1
# 9am to 1030pm(Mon-Sat),11am to 530pm...                1
# Name: TIMING, Length: 2551, dtype: int64

# %%
#temp_dataset=dataset['TIMING'].str.split('(',n=1,expand=False)
temp_dataset=dataset['TIMING'].str.split('(',n=1,expand=True)
temp_dataset
# Out:
#                                      0                                 1
# 0                      12noon to 130am                          Mon-Sun)
# 1                           2pm to 1am                          Mon-Sun)
# 2                        12noon to 1am                          Mon-Sun)
# 3                      12noon to 130am                          Mon-Sun)
# 4                        1130am to 1am                          Mon-Sun)
# ...                                ...                               ...
# 15075  8am to 11pm,12midnight to 115am                          Mon-Sun)
# 15076                    11am to 230am                          Mon-Sun)
# 15077                     11am to 11pm  Mon,Tue,Wed,Thu,Sun),11am to ...
# 15078                    9am to 1230AM                          Mon-Sun)
# 15079       12noon to 330pm,7pm to 1am                          Mon-Sun)
#
# [14138 rows x 2 columns]

# %%
dataset['TIMING']=temp_dataset[0]
dataset['DAYS_OPEN']=temp_dataset[1]
dataset.head()
# Out:
#              NAME  PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki   1200  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda    400                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu   1800                                      Asian,Chinese
# 3  Butterfly High   1000                                      Modern Indian
# 4       BKC  DIVE   1200                   North Indian,Chinese,Continental
#
#                                               REGION     CUSINE TYPE  \
# 0  First International Financial Centre-- Bandra ...   Casual Dining
# 1                                              Mahim  Dessert Parlor
# 2                                               Juhu   Casual Dining
# 3                               Bandra Kurla Complex             Bar
# 4                               Bandra Kurla Complex             Bar
#
#             TIMING  RATING_TYPE  RATING  VOTES DAYS_OPEN
# ...

# %%
#dataset['DAYS_OPEN']=dataset['DAYS_OPEN'].str.replace(')','',case=True)
#dataset['DAYS_OPEN']=dataset['DAYS_OPEN'].str.replace(')','',regex=True)
dataset['DAYS_OPEN']=dataset['DAYS_OPEN'].replace(')','')
dataset.head()
# Out:
#              NAME  PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki   1200  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda    400                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu   1800                                      Asian,Chinese
# 3  Butterfly High   1000                                      Modern Indian
# 4       BKC  DIVE   1200                   North Indian,Chinese,Continental
#
#                                               REGION     CUSINE TYPE  \
# 0  First International Financial Centre-- Bandra ...   Casual Dining
# 1                                              Mahim  Dessert Parlor
# 2                                               Juhu   Casual Dining
# 3                               Bandra Kurla Complex             Bar
# 4                               Bandra Kurla Complex             Bar
#
#             TIMING  RATING_TYPE  RATING  VOTES DAYS_OPEN
# ...

# %%
dataset.isnull().sum()
# Out:
# NAME                 0
# PRICE                0
# CUSINE_CATEGORY      0
# REGION               0
# CUSINE TYPE          0
# TIMING               0
# RATING_TYPE          0
# RATING               0
# VOTES                0
# DAYS_OPEN          160
# dtype: int64

# %%
dataset.fillna('NA',inplace=True)

# %%
dataset
# Out:
#                     NAME  PRICE  \
# 0                Hitchki   1200
# 1           Baba Falooda    400
# 2          Chin Chin Chu   1800
# 3         Butterfly High   1000
# 4              BKC  DIVE   1200
# ...                  ...    ...
# 15075    Tirupati Balaji    500
# 15076  Hari Om Snack Bar    350
# 15077           PitaBurg    400
# 15078     Uncha Otlawala    300
# 15079     Mandarin Panda    400
#
#                                          CUSINE_CATEGORY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...
# 1                           Desserts,Ice Cream,Beverages
# 2                                          Asian,Chinese
# 3                                          Modern Indian
# 4                       North Indian,Chinese,Continental
# ...                                                  ...
# 15075                     Chinese,Fast Food,North Indian
# 15076                     Fast Food,South Indian,Chinese
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14138 entries, 0 to 15079
# Data columns (total 10 columns):
# NAME               14138 non-null object
# PRICE              14138 non-null int64
# CUSINE_CATEGORY    14138 non-null object
# REGION             14138 non-null object
# CUSINE TYPE        14138 non-null object
# TIMING             14138 non-null object
# RATING_TYPE        14138 non-null object
# RATING             14138 non-null float64
# VOTES              14138 non-null int64
# DAYS_OPEN          14138 non-null object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 1.2+ MB

# %%
useless_data=(dataset['RATING']==0.0)|(dataset['VOTES']==0)
dataset[useless_data]
# Out:
#                                 NAME  PRICE  \
# 32     Hotel Annapoorna Refreshments    400
# 34                         Biryani 9    600
# 36                 D Fusion Flavours    350
# 39                      Nation Tadka    400
# 83              Link  Way Restaurant    500
# ...                              ...    ...
# 14998                  Foodies House      0
# 14999                       Khansama      0
# 15010        Earth Cafe @ Waterfield    800
# 15023           How About Some Cream    200
# 15046          Food And Taste Theory    800
#
#                                    CUSINE_CATEGORY  \
# 32                   Maharashtrian,Mughlai,Chinese
# 34                            Biryani,North Indian
# 36                                         Chinese
# 39     North Indian,South Indian,Chinese,Fast Food
# 83                            North Indian,Chinese
# ...                                            ...
# 14998                                      Chinese
# ...

# %%
dataset=dataset[~useless_data]

# %%
dataset
# Out:
#                     NAME  PRICE  \
# 0                Hitchki   1200
# 1           Baba Falooda    400
# 2          Chin Chin Chu   1800
# 3         Butterfly High   1000
# 4              BKC  DIVE   1200
# ...                  ...    ...
# 15075    Tirupati Balaji    500
# 15076  Hari Om Snack Bar    350
# 15077           PitaBurg    400
# 15078     Uncha Otlawala    300
# 15079     Mandarin Panda    400
#
#                                          CUSINE_CATEGORY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...
# 1                           Desserts,Ice Cream,Beverages
# 2                                          Asian,Chinese
# 3                                          Modern Indian
# 4                       North Indian,Chinese,Continental
# ...                                                  ...
# 15075                     Chinese,Fast Food,North Indian
# 15076                     Fast Food,South Indian,Chinese
# ...

# %%
dataset['RATING_TYPE'].value_counts()
# Out:
# Average          5111
# Good             4330
# Very Good        1137
# Excellent          95
# Poor               47
# Veľmi dobré         6
# Dobrze              4
# Skvělá volba        4
# Bardzo dobrze       3
# Dobré               2
# Průměr              2
# Buono               2
# Promedio            2
# İyi                 2
# Bom                 2
# Bueno               2
# Muito Bom           2
# Ortalama            2
# Priemer             2
# Biasa               1
# Excelente           1
# Skvělé              1
# Çok iyi             1
# Media               1
# Muy Bueno           1
# Média               1
# Velmi dobré         1
# Sangat Baik         1
# Baik                1
# Name: RATING_TYPE, dtype: int64

# %%
dataset['RATING_TYPE'].replace(to_replace='Excelente', value='Excellent', inplace=True)
dataset['RATING_TYPE'].replace(to_replace=['Velmi dobré','Veľmi dobré','Muy Bueno','Bardzo dobrze'], value='Very Good', inplace=True)
dataset['RATING_TYPE'].replace(to_replace=['Skvělá volba','Bueno','Skvělé','Buono','Bom','Dobrze','Dobré'], value='Good', inplace=True)
dataset['RATING_TYPE'].replace(to_replace=['Priemer','Média','Çok iyi'], value='Average', inplace=True)
dataset['RATING_TYPE'].replace(to_replace=['Průměr','Promedio','Ortalama','Muito Bom','İyi'], value='Poor', inplace=True)
dataset['RATING_TYPE'].replace(to_replace=['Baik','Biasa','Sangat Baik','Media'], value='Very Poor', inplace=True)
# Out:
# C:\Anaconda3\envs\test\lib\site-packages\pandas\core\generic.py:6786: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dataset['RATING_TYPE'].value_counts()
# Out:
# Average      5115
# Good         4347
# Very Good    1148
# Excellent      96
# Poor           57
# Very Poor       4
# Name: RATING_TYPE, dtype: int64

# %%
dataset['REGION'].value_counts()
# Out:
# Mira Road                                       405
# Malad West                                      308
# Chembur                                         277
# Kharghar                                        268
# Borivali West                                   264
#                                                ...
# Girgaon Chowpatty                                 1
# Kenilworth Mall-- Linking Road-- Bandra West      1
# Sea Princess-- Juhu                               1
# Hotel King's International-- Juhu                 1
# Yogi Midtown-- Turbhe                             1
# Name: REGION, Length: 237, dtype: int64

# %%
dataset['REGION']=dataset['REGION'].str.replace('[a-zA-Z].+-- ','',regex=True)
dataset['REGION']=dataset['REGION'].str.replace(' West| west| East| east','',regex=True)
# Out:
# C:\Anaconda3\envs\test\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Anaconda3\envs\test\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dataset['REGION'].value_counts()
# Out:
# Thane                726
# Mira Road            412
# Andheri              409
# Malad                378
# Kandivali            377
#                     ...
# Majiwada               3
# Flea Bazaar Café       3
# Panvel                 2
# Girgaon Chowpatty      1
# CBD Belapur            1
# Name: REGION, Length: 101, dtype: int64

# %%
#dataset['REGION']=dataset['REGION'].str.replace('','')

# %%
dataset[dataset.duplicated()]
# Out:
#                                 NAME  PRICE  \
# 4064   Sai Sannidhi Restaurant & Bar   1000
# 4068                    Konkan Katta    400
# 4082                  Usmaniya Hotel    600
# 4083                    Gina's Cakes    450
# 4084          Konkanastha Lunch Home    400
# ...                              ...    ...
# 14200      Mezbaan Family Restaurant    350
# 14204               Jyoti Lunch Home    650
# 14253                        On Toes    900
# 14761                    Frosty Farm    400
# 14928               Shree Manu Sagar    300
#
#                             CUSINE_CATEGORY     REGION     CUSINE TYPE  \
# 4064                    North Indian,Konkan    Dahisar   Casual Dining
# 4068          Seafood,Maharashtrian,Malwani   Mahakali     Quick Bites
# 4082                                Mughlai       Fort   Casual Dining
# 4083                                 Bakery  Dombivali            none
# 4084                        Seafood,Malwani    Chakala   Casual Dining
# ...

# %%
dataset=dataset.drop_duplicates()

# %%
dataset
# Out:
#                     NAME  PRICE  \
# 0                Hitchki   1200
# 1           Baba Falooda    400
# 2          Chin Chin Chu   1800
# 3         Butterfly High   1000
# 4              BKC  DIVE   1200
# ...                  ...    ...
# 15075    Tirupati Balaji    500
# 15076  Hari Om Snack Bar    350
# 15077           PitaBurg    400
# 15078     Uncha Otlawala    300
# 15079     Mandarin Panda    400
#
#                                          CUSINE_CATEGORY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...
# 1                           Desserts,Ice Cream,Beverages
# 2                                          Asian,Chinese
# 3                                          Modern Indian
# 4                       North Indian,Chinese,Continental
# ...                                                  ...
# 15075                     Chinese,Fast Food,North Indian
# 15076                     Fast Food,South Indian,Chinese
# ...

# %%
Zomato_df=dataset.copy()

# %%
Zomato_df.head()
# Out:
#              NAME  PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki   1200  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda    400                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu   1800                                      Asian,Chinese
# 3  Butterfly High   1000                                      Modern Indian
# 4       BKC  DIVE   1200                   North Indian,Chinese,Continental
#
#                  REGION     CUSINE TYPE           TIMING RATING_TYPE  RATING  \
# 0  Bandra Kurla Complex   Casual Dining  12noon to 130am   Excellent     4.9
# 1                 Mahim  Dessert Parlor       2pm to 1am   Very Good     4.4
# 2                  Juhu   Casual Dining    12noon to 1am   Very Good     4.2
# 3  Bandra Kurla Complex             Bar  12noon to 130am   Very Good     4.3
# 4  Bandra Kurla Complex             Bar    1130am to 1am   Very Good     4.4
#
#    VOTES DAYS_OPEN
# 0   3529  Mon-Sun)
# ...

# %%
Zomato_df.shape
# Out:
# (10547, 10)

# %%
pip install -U kaleido
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Performing Exploratary Data Analysis

# %% [markdown]
# Q1) How many restaurants are in mumbai for each type of cusine

# %%
figure = px.histogram(Zomato_df, x='CUSINE TYPE',color='CUSINE TYPE', title='No of Restaurants by Cusine Type', labels={'CUSINE TYPE:Cusine Type'})
figure.show()

# %% [markdown]
# Q2) what are the percentage of restaurants by Rating Type in Mumbai?

# %%
rating_type_df=Zomato_df['RATING_TYPE'].value_counts().reset_index()
rating_type_df
# Out:
#        index  RATING_TYPE
# 0    Average         4983
# 1       Good         4263
# 2  Very Good         1145
# 3  Excellent           96
# 4       Poor           56
# 5  Very Poor            4

# %%
rating_type_df.rename(columns={'index':'Rating_Type','RATING_TYPE':'Counts of Restaurant'},inplace=True)
rating_type_df
# Out:
#   Rating_Type  Counts of Restaurant
# 0     Average                  4983
# 1        Good                  4263
# 2   Very Good                  1145
# 3   Excellent                    96
# 4        Poor                    56
# 5   Very Poor                     4

# %%
figure =px.pie(rating_type_df, names='Rating_Type', values='Counts of Restaurant', color='Rating_Type',title='Percentage of Restaurants by Rating Type').update_traces(textposition='inside',textinfo='percent+label')
figure.show()

# %% [markdown]
# Q3)Which are the top 10 highest rated seafood restaurants in Mumabi?

# %%
seafood_df=Zomato_df[Zomato_df['CUSINE_CATEGORY'].str.contains('Seafood')]
seafood_df.sort_values(by='RATING',ascending=False).head(10)
# Out:
#                                           NAME  PRICE  \
# 7104                                Thangabali   1000
# 76                     Ceremonial Kitchen & Co   1000
# 13685                   Maharashtra Lunch Home    600
# 12433                          Quarter Canteen   1100
# 902    The Harbour Bay - SeaFood Kitchen & Bar   2400
# 884        Rajmanya- Seafood family restaurant    800
# 3380                                 Peco Peco    700
# 9954                        Pi Bar and Kitchen   1600
# 903                                Ferry Wharf   1500
# 915                   Monis Bar and Restaurant   1000
#
#                                          CUSINE_CATEGORY           REGION  \
# 7104      Seafood,South Indian,Mangalorean,Andhra,Kerala             Khar
# 76            Seafood,Maharashtrian,North Indian,Chinese  Ghodbunder Road
# 13685               Maharashtrian,Malwani,Konkan,Seafood         Kharghar
# ...

# %% [markdown]
# Q4) Which is the food Truck in Mumbai?

# %%
foodtruck_df=Zomato_df[Zomato_df['CUSINE TYPE']=='Food Truck']
foodtruck_df.sort_values(by='RATING',ascending=False).head(2)
# Out:
#                    NAME  PRICE    CUSINE_CATEGORY   REGION CUSINE TYPE  \
# 262   Dumpling Delights    200              Momos  Matunga  Food Truck
# 1017    Street Food Co.    250  Fast Food,Chinese    Virar  Food Truck
#
#               TIMING RATING_TYPE  RATING  VOTES DAYS_OPEN
# 262   430pm to 930pm   Very Good     4.3    212  Mon-Sun)
# 1017      6pm to 3am   Very Good     4.1    274  Mon-Sun)

# %% [markdown]
# Q5)Which places have the highest rated resturant for each cuisine type in Mumbai?

# %%
highest_rated_df=Zomato_df[Zomato_df['RATING']>=4.5]
highest_rated_df
# Out:
#                              NAME  PRICE  \
# 0                         Hitchki   1200
# 6                  Persian Darbar   1300
# 7                         Tanatan   1500
# 9              Plum by Bent Chair   1800
# 10                  Angrezi Dhaba   1500
# ...                           ...    ...
# 14228  Zaika Crave - Club Aquaria   1300
# 14234                Cone Culture    250
# 15007                  Dessertino    300
# 15051                    Tick-eat    800
# 15056             Daftar Goregaon    750
#
#                                          CUSINE_CATEGORY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...
# 6                   Biryani,North Indian,Chinese,Mughlai
# 7                                          Modern Indian
# 9                                                  Asian
# 10                    North Indian,Chinese,Thai,European
# ...                                                  ...
# 14228          North Indian,Continental,Chinese,Desserts
# ...

# %%
figure=px.histogram(highest_rated_df,x='CUSINE TYPE', title='No of Best Restaurants for each Cuisine Type by Places').update_xaxes(categoryorder='total descending')
figure.show()

# %% [markdown]
# Q6)What is the Avg Price distibution of highest rated restaurant for each cuisine type in Mumbai?

# %%
highest_rated_price_df=highest_rated_df.groupby(by=['REGION','CUSINE TYPE'])['PRICE'].mean().reset_index()
highest_rated_price_df.head(5)
# Out:
#         REGION     CUSINE TYPE   PRICE
# 0  4 Bungalows            none   350.0
# 1      Andheri             Bar  1600.0
# 2      Andheri            Café   800.0
# 3      Andheri   Casual Dining  1212.5
# 4      Andheri  Dessert Parlor   300.0

# %%
import plotly.express as px

# %%
fig = px.scatter(
    highest_rated_price_df,
    x="REGION",
    y="PRICE",
    color="CUSINE TYPE",
    symbol="CUSINE TYPE",
    title="Avg Price Distribution of High Rated Restaurant for Each Cuisine Type"
).update_traces(marker_size=10)

fig.show()

# %% [markdown]
# Q7) What areaa have a large number of Chinese Restaurant Market?

# %%
chinese_df=Zomato_df[Zomato_df['CUSINE_CATEGORY'].str.contains('Chinese')]
#chinese_df=Zomato_df[Zomato_df['CUSINE_CATEGORY']=='Chinese'] --> only give chinese alone
chinese_df
# Out:
#                     NAME  PRICE  \
# 0                Hitchki   1200
# 2          Chin Chin Chu   1800
# 4              BKC  DIVE   1200
# 5       Flea Bazaar Café    800
# 6         Persian Darbar   1300
# ...                  ...    ...
# 15071      Lucknow Zaika    500
# 15072     Zuha's Kitchen    400
# 15075    Tirupati Balaji    500
# 15076  Hari Om Snack Bar    350
# 15079     Mandarin Panda    400
#
#                                          CUSINE_CATEGORY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...
# 2                                          Asian,Chinese
# 4                       North Indian,Chinese,Continental
# 5      American,Asian,Street Food,North Indian,Luckno...
# 6                   Biryani,North Indian,Chinese,Mughlai
# ...                                                  ...
# 15071                               North Indian,Chinese
# 15072                       Chinese,North Indian,Mughlai
# ...

# %%
Chinese_rest_df=chinese_df.groupby(by='REGION').agg({'NAME':'count','PRICE':'mean'}).rename(columns={'NAME':'Count of Restaurants'})
Chinese_rest_df=Chinese_rest_df.sort_values('Count of Restaurants', ascending=False).head(25)
Chinese_rest_df
# Out:
#                       Count of Restaurants       PRICE
# REGION
# Thane                                  348  588.376437
# Mira Road                              224  553.348214
# Malad                                  186  604.032258
# Goregaon                               163  548.773006
# Dombivali                              159  540.899371
# Chembur                                152  604.934211
# Kandivali                              145  572.551724
# Andheri                                137  658.394161
# Kalyan                                 136  523.897059
# Borivali                               131  648.091603
# Kharghar                               125  546.800000
# Mulund                                 124  583.064516
# Vasai                                  116  555.603448
# Vashi                                  114  678.070175
# Bandra                                 104  667.788462
# Ghatkopar                               95  605.789474
# ...

# %%
figure=px.bar(Chinese_rest_df, x='REGION',y='count of Restaurant',color='PRICE',title='No of chinese Restaurant by places')
figure.show()

# %% [markdown]
# Q8)Is there a relation between Price and rating by each cuisine type

# %%
price_rating_df=Zomato_df.groupby(['CUSINE TYPE','RATING'])['PRICE'].mean().reset_index()
price_rating_df
# Out:
#     CUSINE TYPE  RATING       PRICE
# 0        Bakery     2.7  400.000000
# 1        Bakery     2.8  285.714286
# 2        Bakery     2.9  328.571429
# 3        Bakery     3.0  300.000000
# 4        Bakery     3.1  369.117647
# ..          ...     ...         ...
# 278        none     4.3  683.333333
# 279        none     4.4  555.000000
# 280        none     4.5  420.000000
# 281        none     4.6  687.500000
# 282        none     4.7  350.000000
#
# [283 rows x 3 columns]

# %%
figure=px.line(price_rating_df,x='RATING',y='PRICE',color='CUSINE TYPE')
figure.show()

# %% [markdown]
# Q9) Is there a relation between Region and Price

# %%
region_price_df=Zomato_df.groupby(['REGION'])['PRICE'].mean().reset_index()
region_price_df
# Out:
#           REGION       PRICE
# 0    4 Bungalows  528.787879
# 1      7 Andheri  614.285714
# 2         Airoli  452.287582
# 3        Alibaug  665.000000
# 4      Ambernath  514.000000
# ..           ...         ...
# 96      Vikhroli  480.434783
# 97    Vile Parle  464.457831
# 98         Virar  452.027027
# 99        Wadala  427.500000
# 100        Worli  537.012987
#
# [101 rows x 2 columns]

# %%
figure=px.scatter(region_price_df,x='REGION',y='PRICE').update_traces(marker_size=8)
figure.show()

# %% [markdown]
# Q10)Find the list of affordable Restaurants

# %%
max_price=Zomato_df['PRICE'].max()
onefourth_price=max_price/4
onefourth_price
# Out:
# 1250.0

# %%
Zomato_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10547 entries, 0 to 15079
# Data columns (total 10 columns):
# NAME               10547 non-null object
# PRICE              10547 non-null int64
# CUSINE_CATEGORY    10547 non-null object
# REGION             10547 non-null object
# CUSINE TYPE        10547 non-null object
# TIMING             10547 non-null object
# RATING_TYPE        10547 non-null object
# RATING             10547 non-null float64
# VOTES              10547 non-null int64
# DAYS_OPEN          10547 non-null object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 906.4+ KB

# %%
aff_rest_df=Zomato_df[['NAME','PRICE','CUSINE_CATEGORY','REGION','CUSINE TYPE']]
aff_rest_df=aff_rest_df[aff_rest_df['PRICE']<=1250.0]
aff_rest_df.sort_values(by='PRICE',inplace=True)
aff_rest_df
# Out:
#                                                    NAME  PRICE  \
# 6137                                 Sanjog Wine N Dine      5
# 2925                                         Jab We Eat     50
# 9598                                          Ho5 Store     50
# 9589                                   Golden Butterfly    100
# 5916                                  Madhuri Puranpoli    100
# ...                                                 ...    ...
# 2740                                     Peninsula Next   1200
# 5528                                         The Thekka   1200
# 964                                        Bijoli Grill   1250
# 6045  Fabelle at The Chocolate Boutique - ITC Grand ...   1250
# 7301                               SamBar Pub & Kitchen   1250
#
#                                         CUSINE_CATEGORY      REGION  \
# 6137                               North Indian,Chinese       Thane
# 2925  South Indian,North Indian,Maharashtrian,Fast Food     Girgaum
# ...

# %%
highestrate_rest_df=Zomato_df[['NAME','PRICE','CUSINE_CATEGORY','REGION','CUSINE TYPE','RATING']]
highestrate_rest_df=highestrate_rest_df[highestrate_rest_df['RATING']>=4.5]
highestrate_rest_df.sort_values(by='PRICE',inplace=True)
highestrate_rest_df
# Out:
#                                           NAME  PRICE  \
# 1502             Cake Centre-The Dessert Maker    150
# 763                     Curry And Combos Twist    200
# 807                               Moussestruck    200
# 14234                             Cone Culture    250
# 725                                  Belo Pops    300
# ...                                        ...    ...
# 5335                                Mia Cucina   2000
# 1786                             Global Fusion   2000
# 8887                      Drifters Tap Station   2000
# 12625                        House of Mandarin   2100
# 902    The Harbour Bay - SeaFood Kitchen & Bar   2400
#
#                                   CUSINE_CATEGORY                REGION  \
# 1502                                     Desserts     Mohammad Ali Road
# 763                          North Indian,Chinese               Andheri
# 807                                      Desserts  Near Andheri Station
# ...

# %%
highrate_aff_df=pd.merge(aff_rest_df,highestrate_rest_df,how='inner',on=['NAME','REGION'])
highrate_aff_df=highrate_aff_df[['NAME','PRICE_x','CUSINE_CATEGORY_x','REGION','CUSINE TYPE_x']]
highrate_aff_df.rename(columns={'NAME':'NAME','PRICE_x':'PRICE','CUSINE_CATEGORY_x':'CUSINE_CATEGORY','REGION':'REGION','CUSINE TYPE_x':'CUSINE TYPE'},inplace=True)
highrate_aff_df
# Out:
#                              NAME  PRICE  \
# 0   Cake Centre-The Dessert Maker    150
# 1          Curry And Combos Twist    200
# 2                    Moussestruck    200
# 3                    Cone Culture    250
# 4                     Smiley Pops    300
# ..                            ...    ...
# 60         Wild Dining Restaurant   1200
# 61                        Invento   1200
# 62                 Culinary Tales   1200
# 63                        Hitchki   1200
# 64               The Joker Bistro   1200
#
#                                       CUSINE_CATEGORY                REGION  \
# 0                                            Desserts     Mohammad Ali Road
# 1                                North Indian,Chinese               Andheri
# 2                                            Desserts  Near Andheri Station
# 3                                            European              Kharghar
# 4               Desserts,Ice Cream,Beverages,Sandwich               Andheri
# ...

# %% [markdown]
# Q11)Find the list of most Reliable Restaurants

# %%
mean_votes=Zomato_df['VOTES'].mean()
mean_votes
# Out:
# 177.2656679624538

# %%
mean_rest_df=Zomato_df[['NAME','PRICE','CUSINE_CATEGORY','REGION','CUSINE TYPE','VOTES']]
mean_rest_df=mean_rest_df[mean_rest_df['VOTES']>177]
mean_rest_df.sort_values(by='VOTES',inplace=True)
mean_rest_df
# Out:
#                                      NAME  PRICE  \
# 4194                  Sai Sagar Veg Treat    500
# 884   Rajmanya- Seafood family restaurant    800
# 3914                             Ice Cafe    500
# 7897                     Konkan Lajjatdar    500
# 3828     Frozen Delight -The Dessert Cafe    250
# ...                                   ...    ...
# 8539                   Leopold Cafe & Bar   1600
# 1251                         Joey's Pizza    800
# 5337         Chili's American Grill & Bar   1400
# 3751                         Prithvi Cafe    700
# 8897                              Candies    700
#
#                                         CUSINE_CATEGORY    REGION  \
# 4194  North Indian,South Indian,Chinese,Fast Food,Be...    Kalyan
# 884                        Maharashtrian,Konkan,Seafood     Vashi
# 3914                Fast Food,Ice Cream,Beverages,Pizza  Borivali
# 7897   Seafood,Biryani,Beverages,Chinese,Malwani,Konkan   Andheri
# ...

# %%
reliable_rest_df=pd.merge(mean_rest_df,highrate_aff_df,how='inner',on=['NAME','REGION'])
reliable_rest_df=reliable_rest_df[['NAME','PRICE_x','CUSINE_CATEGORY_x','REGION','CUSINE TYPE_x']]
reliable_rest_df.rename(columns={'NAME':'NAME','PRICE_x':'PRICE','CUSINE_CATEGORY_x':'CUSINE_CATEGORY','REGION':'REGION','CUSINE TYPE_x':'CUSINE TYPE'},inplace=True)
reliable_rest_df
# Out:
#                                    NAME  PRICE  \
# 0   Rajmanya- Seafood family restaurant    800
# 1                        Fresh Food Co.    500
# 2                            Dessertino    300
# 3                               Invento   1200
# 4                Maharashtra Lunch Home    600
# 5                              Regano's    600
# 6                       Big Bang Cuurry    350
# 7                           Sandy's Den   1000
# 8                     Angrezi Patiyalaa   1200
# 9                                 Maezo   1000
# 10                         Tossin Pizza    900
# 11                    Little West Pizza    600
# 12              Ceremonial Kitchen & Co   1000
# 13                         Moussestruck    200
# 14                      Daftar Goregaon    750
# 15          Poetry By Love & Cheesecake   1000
# 16                         Makhan Singh    800
# 17                     The Joker Bistro   1200
# 18                         Cone Culture    250
# ...
